# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/mustajabmalik/Downloads/cricket_data.csv")

# %%
df.head(5)
# Out:
#             Player          Team  Runs  Balls  Fours  Sixes  Strike Rate  \
# 0     David Warner     Australia   130     78     23      2       119.84
# 1      Steve Smith  South Africa     0    137      0      0       131.40
# 2  Quinton de Kock       England     4    115     23      0        92.98
# 3         Joe Root      Pakistan   141    132     19      4       138.62
# 4     David Warner      Pakistan   102     81     10      5        54.58
#
#              Venue Result
# 0         The Oval   Lost
# 1  Gaddafi Stadium   Lost
# 2            Lords   Lost
# 3  Gaddafi Stadium   Lost
# 4         Wankhede   Lost

# %%
#plotting
plt.figure(figsize=(9,5))

sns.barplot(x="Player", y="Runs", data=df)
# Out:
# <Axes: xlabel='Player', ylabel='Runs'>

# %%
#plotting
plt.figure(figsize=(15,8))

sns.barplot(x="Player", y="Runs", data=df, estimator = sum)
# Out:
# <Axes: xlabel='Player', ylabel='Runs'>

# %%
#Using the same cricket dataset, create a boxplot using Seaborn to answer the following question:
#"What is the distribution of runs scored by players from each different team?"
sns.boxplot(x="Runs", y= "Team", data= df)
# Out:
# <Axes: xlabel='Runs', ylabel='Team'>

# %%
#Using the same cricket dataset, create a boxplot using Seaborn to answer the following question:
#"What is the distribution of runs scored by players from each different team?"
sns.boxplot(x="Team", y= "Runs", data= df)
# Out:
# <Axes: xlabel='Team', ylabel='Runs'>
