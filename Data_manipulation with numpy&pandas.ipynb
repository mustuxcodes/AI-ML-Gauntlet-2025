# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/mustajabmalik/Downloads/cricket_data.csv")

# %%
df.head(5)
# Out:
#             Player          Team  Runs  Balls  Fours  Sixes  Strike Rate  \
# 0     David Warner     Australia   130     78     23      2       119.84
# 1      Steve Smith  South Africa     0    137      0      0       131.40
# 2  Quinton de Kock       England     4    115     23      0        92.98
# 3         Joe Root      Pakistan   141    132     19      4       138.62
# 4     David Warner      Pakistan   102     81     10      5        54.58
#
#              Venue Result
# 0         The Oval   Lost
# 1  Gaddafi Stadium   Lost
# 2            Lords   Lost
# 3  Gaddafi Stadium   Lost
# 4         Wankhede   Lost

# %%
df.dtypes
# Out:
# Player          object
# Team            object
# Runs             int64
# Balls            int64
# Fours            int64
# Sixes            int64
# Strike Rate    float64
# Venue           object
# Result          object
# dtype: object

# %%
df.isnull()
# Out:
#     Player   Team   Runs  Balls  Fours  Sixes  Strike Rate  Venue  Result
# 0    False  False  False  False  False  False        False  False   False
# 1    False  False  False  False  False  False        False  False   False
# 2    False  False  False  False  False  False        False  False   False
# 3    False  False  False  False  False  False        False  False   False
# 4    False  False  False  False  False  False        False  False   False
# 5    False  False  False  False  False  False        False  False   False
# 6    False  False  False  False  False  False        False  False   False
# 7    False  False  False  False  False  False        False  False   False
# 8    False  False  False  False  False  False        False  False   False
# 9    False  False  False  False  False  False        False  False   False
# 10   False  False  False  False  False  False        False  False   False
# 11   False  False  False  False  False  False        False  False   False
# ...

# %%
 df[df.isnull()]
# Out:
#    Player Team  Runs  Balls  Fours  Sixes  Strike Rate Venue Result
# 0     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 1     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 2     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 3     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 4     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 5     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 6     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 7     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 8     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 9     NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 10    NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 11    NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# 12    NaN  NaN   NaN    NaN    NaN    NaN          NaN   NaN    NaN
# ...

# %%
df.isnull().sum()
# Out:
# Player         0
# Team           0
# Runs           0
# Balls          0
# Fours          0
# Sixes          0
# Strike Rate    0
# Venue          0
# Result         0
# dtype: int64

# %%
df_filled = df.fillna(0)

# %%
df.head(5)
# Out:
#             Player          Team  Runs  Balls  Fours  Sixes  Strike Rate  \
# 0     David Warner     Australia   130     78     23      2       119.84
# 1      Steve Smith  South Africa     0    137      0      0       131.40
# 2  Quinton de Kock       England     4    115     23      0        92.98
# 3         Joe Root      Pakistan   141    132     19      4       138.62
# 4     David Warner      Pakistan   102     81     10      5        54.58
#
#              Venue Result
# 0         The Oval   Lost
# 1  Gaddafi Stadium   Lost
# 2            Lords   Lost
# 3  Gaddafi Stadium   Lost
# 4         Wankhede   Lost

# %%
#change column name
df = df.rename(columns={"Runs" : "Runs scored"})

# %%
df.head(3)
# Out:
#             Player          Team  Runs scored  Balls  Fours  Sixes  \
# 0     David Warner     Australia          130     78     23      2
# 1      Steve Smith  South Africa            0    137      0      0
# 2  Quinton de Kock       England            4    115     23      0
#
#    Strike Rate            Venue Result
# 0       119.84         The Oval   Lost
# 1       131.40  Gaddafi Stadium   Lost
# 2        92.98            Lords   Lost

# %%
#change data type of a column
df["Balls"] = df["Balls"].astype(float)

# %%
df.head(6)
# Out:
#             Player          Team  Runs scored  Balls  Fours  Sixes  \
# 0     David Warner     Australia          130   78.0     23      2
# 1      Steve Smith  South Africa            0  137.0      0      0
# 2  Quinton de Kock       England            4  115.0     23      0
# 3         Joe Root      Pakistan          141  132.0     19      4
# 4     David Warner      Pakistan          102   81.0     10      5
# 5      Aaron Finch     Australia           26   71.0     16      2
#
#    Strike Rate            Venue Result
# 0       119.84         The Oval   Lost
# 1       131.40  Gaddafi Stadium   Lost
# 2        92.98            Lords   Lost
# 3       138.62  Gaddafi Stadium   Lost
# 4        54.58         Wankhede   Lost
# 5        55.60            Lords   Draw

# %%
df.dtypes
# Out:
# Player          object
# Team            object
# Runs scored      int64
# Balls          float64
# Fours            int64
# Sixes            int64
# Strike Rate    float64
# Venue           object
# Result          object
# dtype: object

# %%
#applying any fucntion using .apply function
df["Runs scored again"] = df["Runs scored"].apply(lambda x:x*2)

# %%
df.head(10)
# Out:
#             Player          Team  Runs scored  Balls  Fours  Sixes  \
# 0     David Warner     Australia          130   78.0     23      2
# 1      Steve Smith  South Africa            0  137.0      0      0
# 2  Quinton de Kock       England            4  115.0     23      0
# 3         Joe Root      Pakistan          141  132.0     19      4
# 4     David Warner      Pakistan          102   81.0     10      5
# 5      Aaron Finch     Australia           26   71.0     16      2
# 6  Kane Williamson      Pakistan          136   31.0      7      8
# 7     David Warner      Pakistan           14   58.0      3      4
# 8  Quinton de Kock  South Africa           89  149.0      5      7
# 9         Joe Root     Australia           41  150.0      7      0
#
#    Strike Rate            Venue     Result  Runs scored again
# 0       119.84         The Oval       Lost                260
# 1       131.40  Gaddafi Stadium       Lost                  0
# ...
