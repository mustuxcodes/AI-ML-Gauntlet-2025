# %%
import numpy as np
import pandas as pd

# %%
#two important concepts
#1. Series(1d)
#2. Dataframe(multi dim data)

# %%
#series is 1d data (colmun one) and stores 1 type of data

data = [10,20,30]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#create a series from dictionary
data = {
    "a":1, "b":22, "c":33
    
}
series = pd.Series(data)
print(series)
# Out:
# a     1
# b    22
# c    33
# dtype: int64

# %%
data = [10,20,30]
index =["Mustajab", "Kohli", "ROHIT"]

series = pd.Series(data, index=index)
print(series)
print(type(df))
# Out:
# Mustajab    10
# Kohli       20
# ROHIT       30
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>

# %%
#DATAFRAME

data = [10,20,30]
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     0
# 0  10
# 1  20
# 2  30
# <class 'pandas.core.frame.DataFrame'>

# %%
#create a dataframe from a dictionary of a list  
 
data = {
    "name": ["Mustajab", "Kohli", "Rohit"],
    "age": [22,36,41],
    "city": ["Wah cantt", "Banglore", "Mumbai"]
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#        name  age       city
# 0  Mustajab   22  Wah cantt
# 1     Kohli   36   Banglore
# 2     Rohit   41     Mumbai
# <class 'pandas.core.frame.DataFrame'>

# %%
#creating a df from a list of dictionary
data = [
{"name":"Mustajab", "age":32, "city":"Wah"},
    {"name":"Kohli", "age":34, "city":"Rcb"},
{"name":"Hitman", "age":43, "city":"Bombai"},
]

df = pd.DataFrame(data)
print(df)
# Out:
#        name  age    city
# 0  Mustajab   32     Wah
# 1     Kohli   34     Rcb
# 2    Hitman   43  Bombai

# %%
##reading for a csv using pandas

# %%
df = pd.read_csv("/Users/mustajabmalik/Downloads/Virat-Kohli-International-Cricket-Centuries.csv")
print(df.head())
# Out:
#    No.   Runs       Against  Position  Innings  \
# 0    1    107     Sri Lanka         4        2
# 1    2  102*     Bangladesh         3        2
# 2    3    118     Australia         3        2
# 3    4    105   New Zealand         3        1
# 4    5   100*    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
df = pd.read_csv("/Users/mustajabmalik/Downloads/Virat-Kohli-International-Cricket-Centuries.csv")
print(df.tail())
# Out:
#     No.  Runs       Against  Position  Innings  \
# 75   76   121   West Indies         4        1
# 76   77  122*      Pakistan         3        1
# 77   78  103*    Bangladesh         3        2
# 78   79  101*  South Africa         3        1
# 79   80   117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 75               Queen's Park Oval, Port of Spain     Away  20-Jul-23  Drawn
# 76                  R. Premadasa Stadium, Colombo  Neutral  11-Sep-23    Won
# 77  Maharashtra Cricket Association Stadium, Pune     Home  19-Oct-23    Won
# 78                          Eden Gardens, Kolkata      NaN     05-Nov    Won
# 79                       Wankhede Stadium, Mumbai     Home  15-Nov-23    Won

# %%
#for column index we are reaching
df['Runs']
# Out:
# 0       107
# 1     102*
# 2       118
# 3       105
# 4      100*
#       ...
# 75      121
# 76     122*
# 77     103*
# 78     101*
# 79      117
# Name: Runs, Length: 80, dtype: object

# %%
#for row here it is
df.loc[0]
# Out:
# No.                             1
# Runs                          107
# Against                 Sri Lanka
# Position                        4
# Innings                         2
# Venue       Eden Gardens, Kolkata
# Ground                       Home
# Date                    24-Dec-09
# Result                        Won
# Name: 0, dtype: object

# %%
#index loc
df.iloc[0]
# Out:
# No.                             1
# Runs                          107
# Against                 Sri Lanka
# Position                        4
# Innings                         2
# Venue       Eden Gardens, Kolkata
# Ground                       Home
# Date                    24-Dec-09
# Result                        Won
# Name: 0, dtype: object

# %%
df.loc[0][2]
# Out:
# /var/folders/0p/_s66lk7j5wb5cj0s_z62kh200000gn/T/ipykernel_7624/2880214942.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][2]
# ' Sri Lanka'

# %%
df.iloc[0][2]
# Out:
# /var/folders/0p/_s66lk7j5wb5cj0s_z62kh200000gn/T/ipykernel_7624/2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# ' Sri Lanka'

# %%
df.head(5)
# Out:
#    No.   Runs       Against  Position  Innings  \
# 0    1    107     Sri Lanka         4        2
# 1    2  102*     Bangladesh         3        2
# 2    3    118     Australia         3        2
# 3    4    105   New Zealand         3        1
# 4    5   100*    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
#accesing a specifided element using at function

df.at[5,"Runs"]
#run separately to get answer one by one, this specfically for finding a value at that particular index
df.at[12,"Runs"]
df.at[12,"Runs"]
df.at[12, "Against"]
# Out:
# ' Sri Lanka'

# %%
#accesing a specified element using iat
df.iat[4,5]
# Out:
# 'Sher-e-Bangla Cricket Stadium, Dhaka'

# %%
df.iat[14,5]
# Out:
# 'M. Chinnaswamy Stadium, Bangalore'

# %%
#performing data manipulation in dataframes using pandas
import pandas as pd
data = {
    "name": ["Mustajab", "Kohli", "Rohit"],
    "age": [22,36,41],
    "city": ["Wah cantt", "Banglore", "Mumbai"]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#        name  age       city
# 0  Mustajab   22  Wah cantt
# 1     Kohli   36   Banglore
# 2     Rohit   41     Mumbai

# %%
#adding a column to my dataframe
df["Runs"] = [5000,60000,7000]
df
# Out:
#        name  age       city   Runs
# 0  Mustajab   22  Wah cantt   5000
# 1     Kohli   36   Banglore  60000
# 2     Rohit   41     Mumbai   7000

# %%
#removing a column to my dataframe
df.drop("Runs", axis=1)
# Out:
#        name  age       city
# 0  Mustajab   22  Wah cantt
# 1     Kohli   36   Banglore
# 2     Rohit   41     Mumbai

# %%
df
# Out:
#        name  age       city   Runs
# 0  Mustajab   22  Wah cantt   5000
# 1     Kohli   36   Banglore  60000
# 2     Rohit   41     Mumbai   7000

# %%
#now as you can see above the runs column is there even after we removed it, but to make it permanent we have to place that thing which i am writing it below

df.drop("Runs", axis=1, inplace=True)

# %%
df
# Out:
#        name  age       city
# 0  Mustajab   22  Wah cantt
# 1     Kohli   36   Banglore
# 2     Rohit   41     Mumbai

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   33.000000
# std     9.848858
# min    22.000000
# 25%    29.000000
# 50%    36.000000
# 75%    38.500000
# max    41.000000

# %%
df ['age'] = df['age'] +1

# %%
df
# Out:
#        name  age       city
# 0  Mustajab   23  Wah cantt
# 1     Kohli   37   Banglore
# 2     Rohit   42     Mumbai

# %%
df.drop(0)
# Out:
#     name  age      city
# 1  Kohli   37  Banglore
# 2  Rohit   42    Mumbai

# %%
df
# Out:
#        name  age       city
# 0  Mustajab   23  Wah cantt
# 1     Kohli   37   Banglore
# 2     Rohit   42     Mumbai

# %%
#NOW LEARNING DATA MANIPULATION WITH REAL DATASET LETS SEE WHAT HAPPENS

df = pd.read_csv("/Users/mustajabmalik/Downloads/Virat-Kohli-International-Cricket-Centuries.csv")

# %%
df.head()
# Out:
#    No.   Runs       Against  Position  Innings  \
# 0    1    107     Sri Lanka         4        2
# 1    2  102*     Bangladesh         3        2
# 2    3    118     Australia         3        2
# 3    4    105   New Zealand         3        1
# 4    5   100*    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
df.describe()
# Out:
#            No.   Position   Innings
# count  80.0000  80.000000  80.00000
# mean   40.5000   3.500000   1.67500
# std    23.2379   0.656033   0.67082
# min     1.0000   2.000000   1.00000
# 25%    20.7500   3.000000   1.00000
# 50%    40.5000   3.000000   2.00000
# 75%    60.2500   4.000000   2.00000
# max    80.0000   6.000000   4.00000

# %%
df.dtypes
# Out:
# No.          int64
# Runs        object
# Against     object
# Position     int64
# Innings      int64
# Venue       object
# Ground      object
# Date        object
# Result      object
# dtype: object

# %%
##handling missing values
df.isnull().any()
# Out:
# No.         False
# Runs        False
# Against     False
# Position    False
# Innings     False
# Venue       False
# Ground       True
# Date        False
# Result      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# No.         0
# Runs        0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      1
# Date        0
# Result      0
# dtype: int64

# %%
df_new =df.fillna(0)

# %%
#now renaming the name of the column, here is how we do it
df = df.rename(columns= {"Runs":"Runs Scored"})

# %%
df.head(5)
# Out:
#    No. Runs Scored       Against  Position  Innings  \
# 0    1         107     Sri Lanka         4        2
# 1    2       102*     Bangladesh         3        2
# 2    3         118     Australia         3        2
# 3    4         105   New Zealand         3        1
# 4    5        100*    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
#changing the data type

df["new innings"] = df["Innings"].astype(float)

# %%
df.head(5)
# Out:
#    No. Runs Scored       Against  Position  Innings  \
# 0    1         107     Sri Lanka         4        2
# 1    2       102*     Bangladesh         3        2
# 2    3         118     Australia         3        2
# 3    4         105   New Zealand         3        1
# 4    5        100*    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
df.drop("new innings", axis=1, inplace=True)

# %%
df.dtypes
# Out:
# No.             int64
# Runs Scored    object
# Against        object
# Position        int64
# Innings         int64
# Venue          object
# Ground         object
# Date           object
# Result         object
# dtype: object

# %%
Write a single line of code that returns the "Runs", "Against", and "Venue" for all the centuries where the result was "Won".
Create a boolean mask to filter the DataFrame where the "Result" column is equal to "Won".

Apply this mask to your DataFrame.

Select only the three specified columns ("Runs", "Against", "Venue") from the filtered result.

# %%
mask = df["Result"] == "Won"

# %%
df[mask]
# Out:
#     No. Runs Scored        Against  Position  Innings  \
# 0     1         107      Sri Lanka         4        2
# 1     2       102*      Bangladesh         3        2
# 2     3         118      Australia         3        2
# 3     4         105    New Zealand         3        1
# 4     5        100*     Bangladesh         4        1
# 6     7       112*         England         4        2
# 7     8         117    West Indies         4        2
# 9    10       133*       Sri Lanka         4        2
# 10   11         108      Sri Lanka         3        1
# 11   12         183       Pakistan         3        2
# 12   13         106      Sri Lanka         3        1
# 13   14        128*      Sri Lanka         3        2
# 14   15         103    New Zealand         5        2
# 16   17         107      Australia         5        2
# 18   19         115       Zimbabwe         3        2
# 19   20        100*      Australia         3        2
# ...

# %%
df[mask][["Runs Scored", "Against", "Venue"]]
# Out:
#    Runs Scored        Against  \
# 0          107      Sri Lanka
# 1        102*      Bangladesh
# 2          118      Australia
# 3          105    New Zealand
# 4         100*     Bangladesh
# 6        112*         England
# 7          117    West Indies
# 9        133*       Sri Lanka
# 10         108      Sri Lanka
# 11         183       Pakistan
# 12         106      Sri Lanka
# 13        128*      Sri Lanka
# 14         103    New Zealand
# 16         107      Australia
# 18         115       Zimbabwe
# 19        100*      Australia
# 20       115*       Australia
# 24         136     Bangladesh
# 25         127    West Indies
# 26       139*       Sri Lanka
# 31         107       Pakistan
# 33         138   South Africa
# 36         200    West Indies
# 37         211    New Zealand
# 38       154*     New Zealand
# 39         167        England
# 40         235        England
# 41         122        England
# 42         204     Bangladesh
# 43       111*     West Indies
# ...

# %%
df[df["Result"]=="Won"][["Runs Scored", "Against", "Venue"]]
# Out:
#    Runs Scored        Against  \
# 0          107      Sri Lanka
# 1        102*      Bangladesh
# 2          118      Australia
# 3          105    New Zealand
# 4         100*     Bangladesh
# 6        112*         England
# 7          117    West Indies
# 9        133*       Sri Lanka
# 10         108      Sri Lanka
# 11         183       Pakistan
# 12         106      Sri Lanka
# 13        128*      Sri Lanka
# 14         103    New Zealand
# 16         107      Australia
# 18         115       Zimbabwe
# 19        100*      Australia
# 20       115*       Australia
# 24         136     Bangladesh
# 25         127    West Indies
# 26       139*       Sri Lanka
# 31         107       Pakistan
# 33         138   South Africa
# 36         200    West Indies
# 37         211    New Zealand
# 38       154*     New Zealand
# 39         167        England
# 40         235        England
# 41         122        England
# 42         204     Bangladesh
# 43       111*     West Indies
# ...
